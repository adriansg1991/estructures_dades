# %% [markdown]
# # Lliurament tasca 2: Estructura de dades

# %% [markdown]
# ## NIVELL 1
# ## Exercici 1
#
# Crea una llista que agrupi els mesos de l’any en trimestres (1T: Gener, Febrer i Març, 2T: Abril, Maig, Juny...), és a dir, una llista amb 4 llistes dins.

# %%
mesos = [['Gener','Febrer','Març'],
         ['Abril','Maig', 'Juny'], 
         ['Juliol', 'Agost', 'Setembre'], 
         ['Octubre'],['Novembre'],['Desembre']
        ]

# %% [markdown]
# ## Exercici 2
#
# Crea un codi que et permeti accedir a:
#
# - El segon mes del primer trimestre
# - Els mesos del primer trimestre
# - Setembre i octubre

# %%
# El segon mes del primer trimestre
print(mesos[0][1])
# Out:
# Febrer

# %%
# Els mesos del primer trimestre
print(mesos[0])
# Out:
# ['Gener', 'Febrer', 'Març']

# %%
# Setembre i octubre

print(mesos[2][-1],mesos[3][0])
# Out:
# Setembre Octubre

# %% [markdown]
# ## Exercici 3
#
# Crea una llista amb nombres desordenats i respon a les següents preguntes:
#
# - Quants números hi ha?
# - Quantes vegades apareix el número 3
# - Quantes vegades apareixen els nombres 3 i 4?
# - Quin és el número més gran?
# - Quins són els 3 números més petits?
# - Quin és el rang d’aquesta llista?

# %%
# Creació d'una llista amb nombres desordenats.
import numpy as np

# Genero números aleatoris del 1 al 10 utilitzant el mètode randint de numpy. Posteriorment, converteixo l'array de numpy a llista.
lista = np.random.randint(0,10,(23)).tolist()

print(lista)
# Out:
# [6, 6, 7, 3, 8, 0, 5, 9, 5, 2, 5, 8, 3, 7, 5, 4, 8, 1, 9, 6, 2, 8, 1]

# %%
# Quants números hi ha?
len(lista)
# Out:
# 23

# %%
# Quantes vegades apareix el número 3?
print(f'El número 3 apareix {lista.count(3)} vegada/es.')
# Out:
# El número 3 apareix 2 vegada/es.

# %%
# Quantes vegades apareixen els nombres 3 i 4?
print(f'Els nombres 3 i 4 apareixen {lista.count(3)+lista.count(4)} vegades.')
# Out:
# Els nombres 3 i 4 apareixen 3 vegades.

# %%
# Quin és el número més gran?

print(f'El número més gran de la llista és el {max(lista)}.')
# Out:
# El número més gran de la llista és el 9.

# %%
# Quins són els 3 números més petits?

# Hi ha diferents formes de trobar els números més petits: 

#1
from heapq import nsmallest

print(f'Els números més petits són: {nsmallest(3,lista)}')

# 2
print(f'Els números més petits són: {sorted(lista)[:3]}')
# Out:
# Els números més petits són: [0, 1, 1]
# Els números més petits són: [0, 1, 1]

# %%
# Quin és el rang d’aquesta llista?
print(f'El rang de la llista és: {max(lista) - min(lista)}.')
# Out:
# El rang de la llista és: 9.

# %% [markdown]
# ## Exercici 4
#
# Crea un diccionari de la següent forma i respon a les preguntes:
#
# compra = { "Pomes" : {"Qty": 5, "€": 0.42}, "Peres" : {"Qty": 3, "€": 0.66} }
#
# - Afegeix alguna fruita més
# - Quant han costat les peres en total?
# - Quantes fruites hem comprat en total?
# - Quina és la fruita més cara?

# %%
# Creació d'un diccinari.
compra = { "Pomes" : {"Qty": 5, "€": 0.42}, "Peres" : {"Qty": 3, "€": 0.66} }
compra
# Out:
# {'Pomes': {'Qty': 5, '€': 0.42}, 'Peres': {'Qty': 3, '€': 0.66}}

# %%
# Afegeix alguna fruita més.

# Utilitzo la funció UPDATE per afegir nous elements clau-valor al diccionari.
compra.update({"Maduixes" : {"Qty": 10, "€": 0.70}, "Préssecs" : {"Qty": 5, "€": 0.56}})
compra
# Out:
# {'Pomes': {'Qty': 5, '€': 0.42},
#  'Peres': {'Qty': 3, '€': 0.66},
#  'Maduixes': {'Qty': 10, '€': 0.7},
#  'Préssecs': {'Qty': 5, '€': 0.56}}

# %%
# Quant han costat les peres en total?

cost_peres = 1
for i in compra['Peres'].values():
    cost_peres*=i
print(f'Les peres han costat {cost_peres} €.')
# Out:
# Les peres han costat 1.98 €.

# %%
# Quantes fruites hem comprat en total?

compra_total= 0
for i in compra.values():
    compra_total+= i['Qty']
    
print(f'Hem comprat {compra_total} fruites.')
# Out:
# Hem comprat 23 fruites.

# %%
# Quina és la fruita més cara?
valor_max = 0
for i,j in compra.items():
    if valor_max < j['€']:
        valor_max=j['€']
        fruta_mes_cara = i
print(f' La fruita més cara són els/les {fruta_mes_cara}.')
# Out:
#  La fruita més cara són els/les Maduixes.
